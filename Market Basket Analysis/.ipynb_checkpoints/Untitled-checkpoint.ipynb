# %%
from collections import defaultdict
# import openpyxl
# import csv

TRESHOLD = 700
item_counts = defaultdict(int)
pair_counts = defaultdict(int)
frequent_items = set()
frequent_pairs = set()


def normalizeGroup(*args):
	return str(sorted(args))

# wb = openpyxl.load_workbook('Online_Retail.xlsx')
# sh = wb.get_active_sheet()
# with open('test.csv', 'wb') as f:
#     c = csv.writer(f)
#     for r in sh.rows:
#         c.writerow([cell.value for cell in r])

f = open('Online_Retail.csv', 'r')
lines = f.readlines()
f.close()


tx = defaultdict(list)
for i in range(1, len(lines)):
	data = lines[i].split(',')
	tx[data[0].strip()].append(data[2].strip())


#first pass............................................

#find candidate item
for tid in tx:
	for item in tx[tid]:
		item_counts[item] += 1

#filter for frequent items
for key in item_counts:
	if item_counts[key] >= TRESHOLD:
		frequent_items.add(key)

# for item in frequent_items:
# 	print(item)


#second pass............................................

#find candidate pair
for tid in tx:
	items = tx[tid]
	for idx1 in range(len(items)-1):
		if items[idx1] not in frequent_items:
			continue
		for idx2 in range(idx1+1, len(items)):
			if items[idx2] not in frequent_items:
				continue
			pair = normalizeGroup(items[idx1], items[idx2])
			pair_counts[pair] += 1

#filter frequent pairs
for key in pair_counts:
	if pair_counts[key] >= TRESHOLD:
		frequent_pairs.add(key)

for p in frequent_pairs:
	print(p + ": " + str(pair_counts[p]) + " times.")
# Out:
# ['JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT']: 871 times.
# ['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN']: 599 times.
# ['LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND']: 561 times.
# ['LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN']: 519 times.
# ['RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG']: 528 times.
# ['LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT']: 528 times.
# ['CHARLOTTE BAG SUKI DESIGN', 'RED RETROSPOT CHARLOTTE BAG']: 539 times.
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER']: 553 times.
# ['LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN']: 509 times.
# ['CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG']: 554 times.
# ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN']: 558 times.
# ['JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT']: 577 times.
# ['RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER']: 527 times.
# ['GARDENERS KNEELING PAD CUP OF TEA', 'GARDENERS KNEELING PAD KEEP CALM']: 575 times.
# ['LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT']: 654 times.
# ['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG WOODLAND']: 511 times.
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS']: 552 times.
# ['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT']: 529 times.
# ['DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX']: 580 times.
# ['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED']: 711 times.
# ['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN']: 593 times.
# ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN']: 574 times.
# ['PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']: 693 times.
# ['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED']: 513 times.
# ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE']: 574 times.
# ["PAPER CHAIN KIT 50'S CHRISTMAS", 'PAPER CHAIN KIT VINTAGE CHRISTMAS']: 599 times.
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY']: 565 times.
# ['"KEY FOB', '"KEY FOB']: 809 times.
# ['PARTY BUNTING', 'SPOTTY BUNTING']: 503 times.
# ['JUMBO BAG RED RETROSPOT', 'LUNCH BAG RED RETROSPOT']: 608 times.
# ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES']: 510 times.
# ['WOODEN FRAME ANTIQUE WHITE', 'WOODEN PICTURE FRAME WHITE FINISH']: 559 times.
# ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT']: 595 times.
# ['JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI']: 756 times.
# ['GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']: 861 times.
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT']: 533 times.
# ['JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY']: 697 times.
# ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI']: 535 times.
# ['RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG']: 504 times.
# ['JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI']: 541 times.
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER']: 905 times.
# ['REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER']: 564 times.
# ['HEART OF WICKER LARGE', 'HEART OF WICKER SMALL']: 517 times.
# ['JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG RED RETROSPOT']: 612 times.
# ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT']: 705 times.
# ['LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT']: 589 times.
